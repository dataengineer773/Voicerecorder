# %%
pip install sounddevice
# Out:
# Requirement already satisfied: sounddevice in c:\users\lenovo\appdata\local\programs\python\python314\lib\site-packages (0.5.3)
# Requirement already satisfied: CFFI>=1.0 in c:\users\lenovo\appdata\local\programs\python\python314\lib\site-packages (from sounddevice) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\lenovo\appdata\local\programs\python\python314\lib\site-packages (from CFFI>=1.0->sounddevice) (2.23)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\lenovo\appdata\local\programs\python\python314\lib\site-packages (1.16.3)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\lenovo\appdata\local\programs\python\python314\lib\site-packages (from scipy) (2.3.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install wavio
# Out:
# Requirement already satisfied: wavio in c:\users\lenovo\appdata\local\programs\python\python314\lib\site-packages (0.0.9)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\lenovo\appdata\local\programs\python\python314\lib\site-packages (from wavio) (2.3.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# import required libraries
import sounddevice as sd
from scipy.io.wavfile import write
import wavio as wv

# Sampling frequency
freq = 44100

# Recording duration
duration = 5

# Start recorder with the given values 
# of duration and sample frequency
recording = sd.rec(int(duration * freq), 
                   samplerate=freq, channels=2)

# Record audio for the given number of seconds
sd.wait()

# This will convert the NumPy array to an audio
# file with the given sampling frequency
write("recording0.wav", freq, recording)

# Convert the NumPy array to audio file
wv.write("recording1.wav", recording, freq, sampwidth=2)
